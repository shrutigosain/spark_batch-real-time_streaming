# %% [markdown]
# ### Create a stream of website visits records

# %%
from kafka import KafkaProducer
import datetime
import random
import json
import time

visits_topic="spark.streaming.website.visits"

def string_serializer(value):
    return value.encode('utf-8')
    
visits_producer=KafkaProducer( 
                bootstrap_servers=["localhost:9092"],
                key_serializer=string_serializer,
                value_serializer=string_serializer
                )

countries = ["USA","India","Brazil","Australia","Russia"]
last_actions = ["Catalog","FAQ","Order","ShoppingCart"]

#Generate 100 sample visit records
for i in range(1,100):

    #Create a json string with generated data
    json_record={}
    json_record["country"]=countries[random.randint(0,4)]
    json_record["last_action"]=last_actions[random.randint(0,3)]
    json_record["visit_date"]=datetime.datetime.today().strftime("%Y-%m-%d %H:%M:%S")
    json_record["duration"]=random.randint(1,20)

    #Use country as Key. Each country will go through the same partition, 
    #hence updates to a given country can be handled sequencially
    kafka_key=json_record["country"]
    kafka_value = json.dumps(json_record)
    print(kafka_value)
    visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)

    #sleep for 1-3 seconds
    time.sleep(random.randint(1,3))

visits_producer.flush()
visits_producer.close()
# Out:
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-04-03 20:54:41", "duration": 8}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-04-03 20:54:44", "duration": 8}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:54:47", "duration": 12}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:54:49", "duration": 7}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-04-03 20:54:51", "duration": 14}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-04-03 20:54:53", "duration": 19}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-04-03 20:54:56", "duration": 20}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-04-03 20:54:58", "duration": 15}
# {"country": "India", "last_action": "Order", "visit_date": "2025-04-03 20:54:59", "duration": 19}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:00", "duration": 19}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:55:03", "duration": 4}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-04-03 20:55:05", "duration": 8}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:07", "duration": 17}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-04-03 20:55:08", "duration": 10}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:55:11", "duration": 5}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:14", "duration": 13}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:16", "duration": 6}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:55:19", "duration": 19}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:22", "duration": 20}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-04-03 20:55:24", "duration": 15}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:55:25", "duration": 10}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:28", "duration": 2}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:55:31", "duration": 11}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:32", "duration": 17}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:34", "duration": 1}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:35", "duration": 16}
# {"country": "India", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:36", "duration": 9}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:38", "duration": 17}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:39", "duration": 12}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:42", "duration": 5}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:44", "duration": 15}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:45", "duration": 18}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:46", "duration": 14}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:55:47", "duration": 12}
# {"country": "India", "last_action": "Order", "visit_date": "2025-04-03 20:55:48", "duration": 16}
# {"country": "India", "last_action": "Order", "visit_date": "2025-04-03 20:55:49", "duration": 15}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:55:52", "duration": 13}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:55:53", "duration": 6}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-04-03 20:55:54", "duration": 17}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-04-03 20:55:57", "duration": 1}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:55:58", "duration": 12}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:56:00", "duration": 2}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-04-03 20:56:03", "duration": 16}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:04", "duration": 1}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:06", "duration": 18}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:08", "duration": 9}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:11", "duration": 5}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:12", "duration": 13}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-04-03 20:56:14", "duration": 5}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:16", "duration": 11}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:19", "duration": 1}
# {"country": "India", "last_action": "Catalog", "visit_date": "2025-04-03 20:56:20", "duration": 12}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:22", "duration": 17}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:25", "duration": 2}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:26", "duration": 20}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:27", "duration": 20}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-04-03 20:56:28", "duration": 9}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:56:30", "duration": 11}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:31", "duration": 17}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:33", "duration": 2}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:34", "duration": 2}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:36", "duration": 14}
# {"country": "India", "last_action": "Catalog", "visit_date": "2025-04-03 20:56:39", "duration": 2}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:42", "duration": 18}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:44", "duration": 8}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:56:45", "duration": 7}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:48", "duration": 2}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-04-03 20:56:49", "duration": 7}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:56:52", "duration": 12}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:54", "duration": 6}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:56:56", "duration": 10}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:56:58", "duration": 10}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:01", "duration": 16}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-04-03 20:57:04", "duration": 2}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-04-03 20:57:06", "duration": 11}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-04-03 20:57:07", "duration": 10}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-04-03 20:57:08", "duration": 9}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:09", "duration": 5}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:57:12", "duration": 12}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-04-03 20:57:14", "duration": 8}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-04-03 20:57:15", "duration": 11}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:18", "duration": 19}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:57:20", "duration": 13}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:57:23", "duration": 10}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:24", "duration": 6}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:57:27", "duration": 3}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:30", "duration": 12}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:31", "duration": 18}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:57:34", "duration": 16}
# {"country": "India", "last_action": "Order", "visit_date": "2025-04-03 20:57:37", "duration": 18}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:38", "duration": 20}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:57:41", "duration": 6}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-04-03 20:57:42", "duration": 9}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:44", "duration": 17}
# {"country": "India", "last_action": "Order", "visit_date": "2025-04-03 20:57:46", "duration": 11}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-04-03 20:57:48", "duration": 4}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-04-03 20:57:51", "duration": 2}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:54", "duration": 11}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-04-03 20:57:55", "duration": 17}

# %%
#Consumer test - to test if topic data is published correctly
from kafka import KafkaConsumer

def string_deserializer(value):
    return value.decode('utf-8')
    
visits_consumer=KafkaConsumer(
                bootstrap_servers=["localhost:9092"],
                value_deserializer=string_deserializer,
                auto_offset_reset="latest"
                )

visits_consumer.subscribe(visits_topic)

messages = visits_consumer.poll()
print("Total messages :", len(messages))
for message in messages:
    print("%d:%d: vs=%s" % (message.partition, message.offset, message.value))
# Out:
# Total messages : 0
